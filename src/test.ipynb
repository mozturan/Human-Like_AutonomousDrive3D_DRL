# %%
import os
import gym
import gym_donkeycar
import numpy as np
from environment.rewards import ConstantSpeedReward
import json

path = f"/home/o/Applications/DonkeySimLinux/"
app_path = f"{path}/donkey_sim.x86_64"
port = 9091

conf = {
    "exe_path": app_path,
    "port": port,
    "max_cte": 3
}

env = gym.make("donkey-generated-roads-v0", conf=conf)

obs = env.reset()
done= False
while not(done):
        # action = env.action_space.sample() #! does this work?
        action = [0.1,0.3]
        obs, reward, done, info = env.step(action)
        # print("OBS : ", obs)
        # print("REWARD : ", reward)
        # print("INFO : ", info)
        # print("DONE : ", done)
env.close()
# Out:
# starting DonkeyGym env
# Setting default: start_delay 5.0
# Setting default: frame_skip 1
# Setting default: cam_resolution (120, 160, 3)
# Setting default: log_level 20
# Setting default: host localhost
# Setting default: steer_limit 1.0
# Setting default: throttle_min 0.0
# Setting default: throttle_max 1.0
# donkey subprocess started
# Found path: /home/o/Applications/DonkeySimLinux//donkey_sim.x86_64
# INFO:gym_donkeycar.core.client:connecting to localhost:9091
# /home/o/Documents/donkeycar_rl/.venv/lib/python3.11/site-packages/gym/spaces/box.py:78: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# WARNING:gym_donkeycar.envs.donkey_sim:waiting for sim to start..
# INFO:gym_donkeycar.envs.donkey_sim:on need car config
# INFO:gym_donkeycar.envs.donkey_sim:sending car config.
# loading scene generated_road
# INFO:gym_donkeycar.envs.donkey_sim:sim started!
# closing donkey sim subprocess

# %%
import matplotlib.pyplot as plt
import math
import numpy as np
TARGET_SPEED = 10.0
SIGMA = 2
speed = 0

reward = math.exp((-(TARGET_SPEED- speed)**2)/(2*SIGMA**2))
#Create integer x_values from -10 to 10
x_values = np.arange(0, 20, 0.5) 
print(x_values)
y_values = []
for i in range(len(x_values)):
    reward = math.exp(-(TARGET_SPEED - x_values[i])**2/(2*SIGMA**2))
    y_values.append(reward)

print(y_values)
plt.plot(x_values,y_values)
plt.show()
# Out:
# [ 0.   0.5  1.   1.5  2.   2.5  3.   3.5  4.   4.5  5.   5.5  6.   6.5
#   7.   7.5  8.   8.5  9.   9.5 10.  10.5 11.  11.5 12.  12.5 13.  13.5
#  14.  14.5 15.  15.5 16.  16.5 17.  17.5 18.  18.5 19.  19.5]
# [3.726653172078671e-06, 1.2607105177048523e-05, 4.006529739295107e-05, 0.00011961288358102437, 0.00033546262790251185, 0.00088382630693505, 0.002187491118182885, 0.005086069231012701, 0.011108996538242306, 0.022794180883612344, 0.04393693362340742, 0.07955950871822769, 0.1353352832366127, 0.2162651668298873, 0.32465246735834974, 0.45783336177161427, 0.6065306597126334, 0.7548396019890073, 0.8824969025845955, 0.9692332344763441, 1.0, 0.9692332344763441, 0.8824969025845955, 0.7548396019890073, 0.6065306597126334, 0.45783336177161427, 0.32465246735834974, 0.2162651668298873, 0.1353352832366127, 0.07955950871822769, 0.04393693362340742, 0.022794180883612344, 0.011108996538242306, 0.005086069231012701, 0.002187491118182885, 0.00088382630693505, 0.00033546262790251185, 0.00011961288358102437, 4.006529739295107e-05, 1.2607105177048523e-05]
